# %%
# !pip install opencv-python

# %%
import cv2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (2820, 3760, 3)

# %%
cv2.imshow("dog image",img)
cv2.waitKey(3000)
cv2.destroyAllWindows()

# %%
plt.imshow(img)

# %%
# %matplotlib inline

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img_rgb.shape
# Out:
# (2820, 3760, 3)

# %%
img.shape
# Out:
# (2820, 3760, 3)

# %%
img
# Out:
# array([[[199, 245, 252],
#         [199, 245, 252],
#         [199, 245, 252],
#         ...,
#         [ 76, 186, 186],
#         [ 76, 186, 186],
#         [ 76, 186, 186]],
#
#        [[199, 245, 252],
#         [199, 245, 252],
#         [199, 245, 252],
#         ...,
#         [ 76, 186, 186],
#         [ 76, 186, 186],
#         [ 76, 186, 186]],
#
#        [[199, 245, 252],
#         [199, 245, 252],
#         [199, 245, 252],
#         ...,
#         [ 77, 187, 187],
#         [ 77, 187, 187],
#         [ 77, 187, 187]],
#
#        ...,
#
#        [[ 60, 215, 211],
#         [ 60, 215, 211],
#         [ 61, 216, 212],
#         ...,
#         [104, 169, 160],
#         [105, 170, 161],
#         [108, 173, 164]],
#
#        [[ 60, 215, 211],
#         [ 60, 215, 211],
#         [ 61, 216, 212],
#         ...,
#         [104, 169, 160],
#         [105, 170, 161],
#         [109, 174, 165]],
#
#        [[ 60, 215, 211],
#         [ 60, 215, 211],
#         [ 61, 216, 212],
# ...

# %%
img_rgb
# Out:
# array([[[252, 245, 199],
#         [252, 245, 199],
#         [252, 245, 199],
#         ...,
#         [186, 186,  76],
#         [186, 186,  76],
#         [186, 186,  76]],
#
#        [[252, 245, 199],
#         [252, 245, 199],
#         [252, 245, 199],
#         ...,
#         [186, 186,  76],
#         [186, 186,  76],
#         [186, 186,  76]],
#
#        [[252, 245, 199],
#         [252, 245, 199],
#         [252, 245, 199],
#         ...,
#         [187, 187,  77],
#         [187, 187,  77],
#         [187, 187,  77]],
#
#        ...,
#
#        [[211, 215,  60],
#         [211, 215,  60],
#         [212, 216,  61],
#         ...,
#         [160, 169, 104],
#         [161, 170, 105],
#         [164, 173, 108]],
#
#        [[211, 215,  60],
#         [211, 215,  60],
#         [212, 216,  61],
#         ...,
#         [160, 169, 104],
#         [161, 170, 105],
#         [165, 174, 109]],
#
#        [[211, 215,  60],
#         [211, 215,  60],
#         [212, 216,  61],
# ...

# %%
plt.imshow(img_rgb)
plt.show()

# %%
img_grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
img_grey.shape
# Out:
# (2820, 3760)

# %%
plt.imshow(img_grey, cmap='gray')

# %%
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
plt.imshow(img_hsv)

# %%
img_rgb.shape
# Out:
# (2820, 3760, 3)

# %%
plt.imshow(img_rgb)

# %%
img_new_rgb = cv2.resize(img_rgb,(500,500))

# %%
img_new_rgb.shape
# Out:
# (500, 500, 3)

# %%
plt.imshow(img_new_rgb)

# %%
img_blur = cv2.blur(img_new_rgb,(40,40))

# %%
plt.imshow(img_blur)

# %%
img_rgb.shape
# Out:
# (2820, 3760, 3)

# %%
rows, cols = img_rgb.shape[:-1]

# %%
M = cv2.getRotationMatrix2D((rows/2,cols/2), 75,0.8)

# %%
i = cv2.warpAffine(img_rgb,M, (cols,rows))

# %%
plt.imshow(i)

# %%
M = np.float32([[1,0.1,-50], [0,1,-200]])

# %%
M
# Out:
# array([[ 1.e+00,  1.e-01, -5.e+01],
#        [ 0.e+00,  1.e+00, -2.e+02]], dtype=float32)

# %%
i = cv2.warpAffine(img_rgb,M, (cols,rows))

# %%
plt.imshow(i)

# %%
i = cv2.Canny(img_rgb,60,60)

# %%
plt.imshow(i)

# %%
import cv2

# %%
cam = cv2.VideoCapture(0)

while True:
    ret, frame = cam.read()
    if ret==False:
        continue
        
    cv2.imshow('My image', frame)
    key_pressed = cv2.waitKey(1) & 0xFF
    if key_pressed==ord('q'):
        break
cam.release()
cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img1 = plt.imread('img1.jpg')
img2 = plt.imread('img2.jpg')
img3 = plt.imread('img3.jpg')
img4 = plt.imread('img4.jpg')
img5 = plt.imread('img5.jpeg')

# %%
img1 = cv2.resize(img1, (200,200))
img2 = cv2.resize(img2, (200,200))
img3 = cv2.resize(img3, (200,200))
img4 = cv2.resize(img4, (200,200))
img5 = cv2.resize(img5, (100,100))

# %%
final_img = np.zeros((430,430,3), dtype = 'uint8')

# %%
final_img.shape
# Out:
# (430, 430, 3)

# %%
final_img[10:210,10:210,:] = img1
final_img[10:210,220:420,:] = img2
final_img[220:420,10:210,:] = img3
final_img[220:420,220:420,:] = img4
final_img[155:275,155:275,:] = center_img

# %%
plt.axis('off')
plt.imshow(final_img)
plt.show()

# %%
center_img = np.zeros((120,120,3), dtype= 'uint8')

# %%
center_img[10:110,10:110,:] = img5

# %%
plt.imshow(center_img)

# %%
plt.imsave('my_finallll_img.jpg', final_img)

# %% [markdown]
# # Webscraping

# %%
# !pip install requests

# %%
import requests
import json

# %%
res = requests.get('https://www.boredapi.com/api/activity')

# %%
res.status_code
# Out:
# 200

# %%
type(res.text)
# Out:
# str

# %%
res.text
# Out:
# '{"activity":"Practice coding in your favorite lanaguage","type":"recreational","participants":1,"price":0,"link":"","key":"7096020","accessibility":0.1}'

# %%
activity = json.loads(res.text)

# %%
activity['activity']
# Out:
# 'Practice coding in your favorite lanaguage'

# %%
activity.get('activity')
# Out:
# 'Practice coding in your favorite lanaguage'

# %%
res = requests.get('https://api.ipify.org')

# %%
res.status_code
# Out:
# 200

# %%
res.text
# Out:
# '160.202.38.173'

# %%
res = requests.get('http://universities.hipolabs.com/search?country=India')

# %%
res.status_code
# Out:
# 200

# %%
type(res.text)
# Out:
# str

# %%
universites = json.loads(res.text)

# %%
universites[200]
# Out:
# {'country': 'India',
#  'web_pages': ['http://www.kukinfo.com/'],
#  'name': 'Kurukshetra University',
#  'state-province': None,
#  'alpha_two_code': 'IN',
#  'domains': ['kukinfo.com']}

# %%
res = requests.get('http://api.tvmaze.com/search/shows?q=friends')

# %%
res.status_code
# Out:
# 200

# %%
res.text
# Out:
# '[{"score":0.9092685,"show":{"id":431,"url":"https://www.tvmaze.com/shows/431/friends","name":"Friends","type":"Scripted","language":"English","genres":["Comedy","Romance"],"status":"Ended","runtime":30,"averageRuntime":30,"premiered":"1994-09-22","ended":"2004-05-06","officialSite":null,"schedule":{"time":"20:00","days":["Thursday"]},"rating":{"average":8.5},"weight":99,"network":{"id":1,"name":"NBC","country":{"name":"United States","code":"US","timezone":"America/New_York"},"officialSite":"https://www.nbc.com/"},"webChannel":null,"dvdCountry":null,"externals":{"tvrage":3616,"thetvdb":79168,"imdb":"tt0108778"},"image":{"medium":"https://static.tvmaze.com/uploads/images/medium_portrait/41/104550.jpg","original":"https://static.tvmaze.com/uploads/images/original_untouched/41/104550.jpg"},"summary":"<p>Six young (20-something) people from New York City (Manhattan), on their own and struggling to survive in the real world, find the companionship, comfort and support they get from each 
# ...

# %%
shows = json.loads(res.text)

# %%
shows[0].get('show').get('name')
# Out:
# 'Friends'

# %%
#requests.get('https://restcountries.eu/rest/v2/all')

# %%
res = requests.get('https://static.toiimg.com/thumb/msid-60132235,imgsize-169468,width-800,height-600,resizemode-75/60132235.jpg')

# %%
res.status_code
# Out:
# 200

# %%
bin_data = res.content

# %%
with open('myfavimage.jpg', 'wb') as f:
    f.write(bin_data)

# %%
# !pip install bs4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
import re
import bs4

# %%
res = requests.get('https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_and_their_capitals_in_native_languages')

# %%
res.status_code
# Out:
# 200

# %%
text = res.content

# %%
soup = bs4.BeautifulSoup(text)

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.title
# Out:
# <title>List of countries and dependencies and their capitals in native languages - Wikipedia</title>

# %%
soup.script
# Out:
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"cee24587-0f1b-4f78-be57-a1edad60ddf0","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_countries_and_dependencies_and_their_capitals_in_native_languages","wgTitle":"List of countries and dependencies and their capitals in native languages","wgCurRevisionId":1114148401,"wgRevisionId":1114148401,"wgArticleId":1008653,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description is different from Wikidata","Articles that may contain original research from November 2019",
# ...

# %%
soup.link
# Out:
# <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>

# %%
soup.h1.text
# Out:
# 'List of countries and dependencies and their capitals in native languages'

# %%
soup.h2
# Out:
# <h2><span class="mw-headline" id="A">A</span></h2>

# %%
soup.find('h1')
# Out:
# <h1 class="firstHeading mw-first-heading" id="firstHeading"><span class="mw-page-title-main">List of countries and dependencies and their capitals in native languages</span></h1>

# %%
soup.h1
# Out:
# <h1 class="firstHeading mw-first-heading" id="firstHeading"><span class="mw-page-title-main">List of countries and dependencies and their capitals in native languages</span></h1>

# %%
soup.find('h2')
# Out:
# <h2><span class="mw-headline" id="A">A</span></h2>

# %%
all_tables = soup.find_all('table',attrs={'class':'wikitable'})

# %%
all_tables
# Out:
# [<table class="wikitable" style="text-align:center;">
#  <tbody><tr style="background:#ccc;">
#  <th style="width:175px;">Country (<a class="mw-redirect" href="/wiki/Exonym" title="Exonym">exonym</a>)
#  </th>
#  <th style="width:175px;">Capital (<a class="mw-redirect" href="/wiki/Exonym" title="Exonym">exonym</a>)
#  </th>
#  <th style="width:175px;">Country (<a class="mw-redirect" href="/wiki/Endonym" title="Endonym">endonym</a>)
#  </th>
#  <th style="width:175px;">Capital (<a class="mw-redirect" href="/wiki/Endonym" title="Endonym">endonym</a>)
#  </th>
#  <th style="width:175px;">Official or native language(s) (alphabet/script)
#  </th></tr>
#  <tr>
#  <td><b><a href="/wiki/Afghanistan" title="Afghanistan">Afghanistan</a></b></td>
#  <td><a href="/wiki/Kabul" title="Kabul">Kabul</a></td>
#  <td><b>Afghanestan</b><br/>افغانستان</td>
#  <td><b>Kabul</b><br/>كابل</td>
# ...

# %%
len(all_tables)
# Out:
# 25

# %%
D_table  = all_tables[3].find_all('tr')[1:]

# %%
len(D_table)
# Out:
# 4

# %%
all_tds = D_table[0].find_all('td')

# %%
len(all_tds)
# Out:
# 5

# %%
all_tds[0].img.attrs['src']
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/9/9c/Flag_of_Denmark.svg/20px-Flag_of_Denmark.svg.png'

# %%
country  = all_tds[0].text

# %%
capital  = all_tds[1].text

# %%
language  = all_tds[-1].text

# %%
print(country,capital,language)
# Out:
#  Denmark Copenhagen Danish

# %%
all_tds[0]
# Out:
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="387" data-file-width="512" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9c/Flag_of_Denmark.svg/20px-Flag_of_Denmark.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9c/Flag_of_Denmark.svg/31px-Flag_of_Denmark.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9c/Flag_of_Denmark.svg/40px-Flag_of_Denmark.svg.png 2x" width="20"/></span> <b><a href="/wiki/Denmark" title="Denmark">Denmark</a></b></td>

# %%
df = pd.DataFrame({}, columns=['Country', 'Capital', 'Language'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [Country, Capital, Language]
# Index: []

# %%
for onetable in all_tables:
    all_rows = onetable.find_all('tr')[1:]
    for tr in all_rows:
        all_tds = tr.find_all('td')
        
        country = all_tds[0].text
        capital = all_tds[1].text
        language = all_tds[-1].text
        ele = {'Country':country,'Capital':capital,'Language':language}
        
        df = df.append(ele,ignore_index=True)
        print(country,'==', capital,'==', language)
        print()
# Out:
# C:\Users\skme2\AppData\Local\Temp\ipykernel_19036\263623599.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ele,ignore_index=True)
# C:\Users\skme2\AppData\Local\Temp\ipykernel_19036\263623599.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ele,ignore_index=True)
# C:\Users\skme2\AppData\Local\Temp\ipykernel_19036\263623599.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ele,ignore_index=True)
# C:\Users\skme2\AppData\Local\Temp\ipykernel_19036\263623599.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ele,ignore_index=True)
# ...

# %%
df
# Out:
#                     Country           Capital  \
# 0               Afghanistan             Kabul
# 1                   Albania            Tirana
# 2                   Algeria           Algiers
# 3         American Samoa[1]         Pago Pago
# 4                   Andorra  Andorra la Vella
# ..                      ...               ...
# 237                 Vietnam             Hanoi
# 238   Wallis and Futuna[10]          Mata Utu
# 239                   Yemen            Sana'a
# 240                  Zambia            Lusaka
# 241                Zimbabwe            Harare
#
#                                               Language
# 0                         Pashto/Dari(Arabic script)\n
# 1                                           Albanian\n
# 2    Berber language(Tifinagh script)Arabic(Arabic ...
# 3                                      SamoanEnglish\n
# 4                                            Catalan\n
# ..                                                 ...
# ...

# %%
df.shape
# Out:
# (242, 3)

# %%
df.head()
# Out:
#               Country           Capital  \
# 0         Afghanistan             Kabul
# 1             Albania            Tirana
# 2             Algeria           Algiers
# 3   American Samoa[1]         Pago Pago
# 4             Andorra  Andorra la Vella
#
#                                             Language
# 0                       Pashto/Dari(Arabic script)\n
# 1                                         Albanian\n
# 2  Berber language(Tifinagh script)Arabic(Arabic ...
# 3                                    SamoanEnglish\n
# 4                                          Catalan\n

# %%
df['Language'] = df.Language.apply(lambda x:x[:-1])

# %%
df.head()
# Out:
#               Country           Capital  \
# 0         Afghanistan             Kabul
# 1             Albania            Tirana
# 2             Algeria           Algiers
# 3   American Samoa[1]         Pago Pago
# 4             Andorra  Andorra la Vella
#
#                                             Language
# 0                         Pashto/Dari(Arabic script)
# 1                                           Albanian
# 2  Berber language(Tifinagh script)Arabic(Arabic ...
# 3                                      SamoanEnglish
# 4                                            Catalan

# %%
df.to_csv('myfirstscrapping.csv', index=False)

# %%
df['Country'] = df['Country'].apply(lambda x:re.sub('\[.*\]',"",x.strip()))

# %%
s = "helloworld[3]"
re.sub('\[.*\]',"",s)
# Out:
# 'helloworld'

# %%
df.to_csv('myfirstscrapping.csv', index=False)

# %%
countries_df  = pd.read_csv('myfirstscrapping.csv')

# %%
countries_df
# Out:
#                Country           Capital  \
# 0          Afghanistan             Kabul
# 1              Albania            Tirana
# 2              Algeria           Algiers
# 3       American Samoa         Pago Pago
# 4              Andorra  Andorra la Vella
# ..                 ...               ...
# 237            Vietnam             Hanoi
# 238  Wallis and Futuna          Mata Utu
# 239              Yemen            Sana'a
# 240             Zambia            Lusaka
# 241           Zimbabwe            Harare
#
#                                               Language
# 0                           Pashto/Dari(Arabic script)
# 1                                             Albanian
# 2    Berber language(Tifinagh script)Arabic(Arabic ...
# 3                                        SamoanEnglish
# 4                                              Catalan
# ..                                                 ...
# 237                                         Vietnamese
# ...

# %%
import requests
import bs4

# %%
res = requests.get('https://www.passiton.com/inspirational-quotes?page=2')

# %%
res.status_code
# Out:
# 200

# %%
data = res.content

# %%
soup = bs4.BeautifulSoup(data)

# %%
box = soup.find('div', attrs={'id':'all_quotes'})

# %%
imgs  = box.find_all('img')

# %%
imgs
# Out:
# [<img alt="We lose ourselves in the things we love. We find ourselves there, too. #&lt;Author:0x00007f3a739bfe38&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/6459/medium/20220823_tuesday_quote.jpg" width="310"/>,
#  <img alt="You yourself, as much as anybody in the entire universe deserve your love and affection. #&lt;Author:0x00007f3a73a69e88&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7692/medium/20220822_monday_quote.jpg" width="310"/>,
#  <img alt="You have the capability to change your life all with a simple shift in perspective. #&lt;Author:0x00007f3a73a48738&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8356/medium/20220819_friday_quote.jpg" width="310"/>,
# ...

# %%
len(imgs)
# Out:
# 33

# %%
img_url = imgs[0].attrs['src']

# %%
img_res = requests.get(img_url)

# %%
img_content = img_res.content

# %%
with open('quotes.jpg', 'wb') as f:
    f.write(img_content)

# %%
for idx,i in enumerate(imgs,32):
    img_url = i.attrs['src']
    
    res = requests.get(img_url)
    img_content = res.content
    
    with open(f"quotes_{idx}.jpg","wb") as f:
        f.write(img_content)

# %%
l = ["apple","mango", "banana", "grapes"]

# %%
for idx,i in enumerate(l,32):
    print(idx,i)
# Out:
# 32 apple
# 33 mango
# 34 banana
# 35 grapes
