# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as conn

# %%
mydb = conn.Connect(host = 'localhost', user = 'root', password = 'root')

# %%
mydb

# %%
cursor = mydb.cursor()

# %%
cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('crmdb',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('world',)]

# %%
cursor = mydb.cursor()

# %%
cursor.execute('create database testdb')

# %%
cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('crmdb',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('testdb',),
#  ('world',)]

# %%
cursor.execute('create database sanjdbineuron')

# %%
cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('crmdb',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sanjdbineuron',),
#  ('sys',),
#  ('testdb',),
#  ('world',)]

# %%
cursor.execute('create table sanjdbineuron.Employee1(studentid INT(10), firstname VARCHAR(30), lastname VARCHAR(30), registration_id INT(10), class VARCHAR(30))')

# %%
cursor.execute('use sanjdbineuron')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('employee1',)]

# %%
cursor.execute('insert into sanjdbineuron.Employee1 values(101, "jone", "rem", 1,"FSDS")')

# %%
mydb.commit()

# %%
cursor.execute('select * from sanjdbineuron.employee1')

# %%
cursor.fetchall()
# Out:
# [(101, 'jone', 'rem', 1, 'FSDS')]

# %%
cursor.execute('insert into sanjdbineuron.Employee1 values(102, "smith", "sem", 2, "MLDL")')

# %%
mydb.commit()

# %%
cursor.execute('select * from sanjdbineuron.employee1')

# %%
cursor.fetchall()
# Out:
# [(101, 'jone', 'rem', 1, 'FSDS'), (102, 'smith', 'sem', 2, 'MLDL')]

# %%
cursor.execute('insert into sanjdbineuron.employee1 values(103,"mark","jan",3,"cv")')

# %%
mydb.commit()

# %%
cursor.execute('select * from sanjdbineuron.employee1')

# %%
cursor.fetchall()
# Out:
# [(101, 'jone', 'rem', 1, 'FSDS'),
#  (102, 'smith', 'sem', 2, 'MLDL'),
#  (103, 'mark', 'jan', 3, 'cv')]

# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon_data.csv')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.rename(columns= {'#':'Sno'}, inplace=True)

# %%
df.head()
# Out:
#    Sno                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1              Bulbasaur  Grass  Poison  45      49       49       65
# 1    2                Ivysaur  Grass  Poison  60      62       63       80
# 2    3               Venusaur  Grass  Poison  80      82       83      100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4    4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as conn

# %%
mydb1 = conn.Connect(host = 'localhost', user = 'root', password = 'root')

# %%
cursor = mydb1.cursor()

# %%
cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('crmdb',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('pokemon',),
#  ('sakila',),
#  ('sanjdbineuron',),
#  ('sys',),
#  ('testdb',),
#  ('world',)]

# %%
cursor.execute('create database pokemondata')

# %%
cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('crmdb',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('pokemon',),
#  ('pokemondata',),
#  ('sakila',),
#  ('sanjdbineuron',),
#  ('sys',),
#  ('testdb',),
#  ('world',)]

# %%
cursor.execute('drop database pokemon')

# %%
cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('crmdb',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('pokemondata',),
#  ('sakila',),
#  ('sanjdbineuron',),
#  ('sys',),
#  ('testdb',),
#  ('world',)]

# %%
cursor.execute('create table pokemondata.pokemon(Sno. INT(20), Name varchar(50), Type 1  )')

# %%
df.columns
# Out:
# Index(['Sno.', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.to_csv('newpokemon.csv')

# %%
df.head()
# Out:
#    Sno.                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0     1              Bulbasaur  Grass  Poison  45      49       49       65
# 1     2                Ivysaur  Grass  Poison  60      62       63       80
# 2     3               Venusaur  Grass  Poison  80      82       83      100
# 3     3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4     4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.rename(columns={'Type 1':'Type_1','Type 2':'Type_2',"Sp. Atk":"Sp_atk", "Sp. Def": "Sp_def"}, inplace=True)

# %%
df.to_csv('newpokemon.csv', index=False)

# %%
df = pd.read_csv('newpokemon.csv')

# %%
df.head()
# Out:
#    Sno  HP  Attack  Defense  Sp_atk  Sp_def  Speed  Generation
# 0    1  45      49       49      65      65     45           1
# 1    2  60      62       63      80      80     60           1
# 2    3  80      82       83     100     100     80           1
# 3    3  80     100      123     122     120     80           1
# 4    4  39      52       43      60      50     65           1

# %%
cursor.execute('create table pokemondata.pokemon2(Sno INT(20), HP INT(50), Attack INT(50), Defense INT(50), Sp_atk INT(50), Sp_def INT(50), Speed INT(50), Generation INT(50))')

# %%
cursor.execute('use pokemondata')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('pokemon1',), ('pokemon2',)]

# %%
cursor.execute('drop table pokemondata.pokemon1')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('pokemon2',)]

# %%
file = open('newpokemon.csv', 'r')

# %%
import csv

# %%
file.read()
# Out:
# "Sno,Name,Type_1,Type_2,HP,Attack,Defense,Sp_atk,Sp_def,Speed,Generation,Legendary\n1,Bulbasaur,Grass,Poison,45,49,49,65,65,45,1,False\n2,Ivysaur,Grass,Poison,60,62,63,80,80,60,1,False\n3,Venusaur,Grass,Poison,80,82,83,100,100,80,1,False\n3,VenusaurMega Venusaur,Grass,Poison,80,100,123,122,120,80,1,False\n4,Charmander,Fire,,39,52,43,60,50,65,1,False\n5,Charmeleon,Fire,,58,64,58,80,65,80,1,False\n6,Charizard,Fire,Flying,78,84,78,109,85,100,1,False\n6,CharizardMega Charizard X,Fire,Dragon,78,130,111,130,85,100,1,False\n6,CharizardMega Charizard Y,Fire,Flying,78,104,78,159,115,100,1,False\n7,Squirtle,Water,,44,48,65,50,64,43,1,False\n8,Wartortle,Water,,59,63,80,65,80,58,1,False\n9,Blastoise,Water,,79,83,100,85,105,78,1,False\n9,BlastoiseMega Blastoise,Water,,79,103,120,135,115,78,1,False\n10,Caterpie,Bug,,45,30,35,20,20,45,1,False\n11,Metapod,Bug,,50,20,55,25,25,30,1,False\n12,Butterfree,Bug,Flying,60,45,50,90,80,70,1,False\n13,Weedle,Bug,Poison,40,35,30,20,20,50,1,False\n14,Kakuna,Bug,
# ...

# %%
with open('newpokemon.csv', 'r') as f:
    csv_reader = csv.reader(f,delimiter = '\n')

# %%
csv_reader

# %%
df.head()
# Out:
#    Sno                   Name Type_1  Type_2  HP  Attack  Defense  Sp_atk  \
# 0    1              Bulbasaur  Grass  Poison  45      49       49      65
# 1    2                Ivysaur  Grass  Poison  60      62       63      80
# 2    3               Venusaur  Grass  Poison  80      82       83     100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123     122
# 4    4             Charmander   Fire     NaN  39      52       43      60
#
#    Sp_def  Speed  Generation  Legendary
# 0      65     45           1      False
# 1      80     60           1      False
# 2     100     80           1      False
# 3     120     80           1      False
# 4      50     65           1      False

# %%
cursor.execute('insert into pokemondata.pokemon1 values(1, "Bulbasaur", "Grass", "Poison", 45,49,49,65,65,45,1, "False")')

# %%
mydb1.commit()

# %%
cursor.execute("select * from pokemondata.pokemon1")

# %%
cursor.fetchall()
# Out:
# [(1, 'Bulbasaur', 'Grass', 'Poison', 45, 49, 49, 65, 65, 45, 1, 'False')]

# %%
df.head()
# Out:
#    Sno                   Name Type_1  Type_2  HP  Attack  Defense  Sp_atk  \
# 0    1              Bulbasaur  Grass  Poison  45      49       49      65
# 1    2                Ivysaur  Grass  Poison  60      62       63      80
# 2    3               Venusaur  Grass  Poison  80      82       83     100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123     122
# 4    4             Charmander   Fire     NaN  39      52       43      60
#
#    Sp_def  Speed  Generation  Legendary
# 0      65     45           1      False
# 1      80     60           1      False
# 2     100     80           1      False
# 3     120     80           1      False
# 4      50     65           1      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Sno         800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type_1      800 non-null    object
#  3   Type_2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp_atk      800 non-null    int64
#  8   Sp_def      800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df.drop(columns=['Name', 'Type_1', 'Type_2','Legendary'], inplace=True)

# %%
with open('newpokemon.csv', 'r') as f:
    csv_reader = csv.reader(f,delimiter = '\n')
    for data in  csv_reader:
        cursor.execute(f'insert into pokemon2 values ({str(data[0])})')
mydb1.commit()

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 9640-2F36
#
#  Directory of C:\Users\nimbu\Documents\Python_script
#
# 04/27/2022  10:38 AM    <DIR>          .
# 04/27/2022  10:20 AM    <DIR>          ..
# 04/25/2022  01:30 PM    <DIR>          .ipynb_checkpoints
# 04/13/2022  12:31 PM    <DIR>          blue
# 04/14/2022  12:35 PM    <DIR>          Courier invoices
# 04/21/2022  06:55 PM    <DIR>          courier_bill
# 04/22/2022  12:46 PM           170,781 Courierwise Shipment bill compilation.ipynb
# 04/20/2022  03:08 PM    <DIR>          development
# 04/20/2022  03:05 PM           612,069 development.zip
# 04/21/2022  07:44 PM         2,902,669 DTDC_finall_march_22.csv
# 04/22/2022  10:48 AM         2,898,050 DTDC_finalll_march_22.csv
# 04/25/2022  10:39 AM    <DIR>          ecomm
# 04/25/2022  10:33 AM               588 EDA and Feature Engg.ipynb
# 04/27/2022  01:58 PM    <DIR>          employee_practice
# 04/25/2022  02:26 PM    <DIR>          final
# ...

# %%
file = open('glass.csv', 'r')

# %%
file.read()
# Out:
# 'RI,Na,Mg,Al,Si,K,Ca,Ba,Fe,Type\n1.52101,13.64,4.49,1.1,71.78,0.06,8.75,0,0,1\n1.51761,13.89,3.6,1.36,72.73,0.48,7.83,0,0,1\n1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0,0,1\n1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0,0,1\n1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0,0,1\n1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0,0.26,1\n1.51743,13.3,3.6,1.14,73.09,0.58,8.17,0,0,1\n1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0,0,1\n1.51918,14.04,3.58,1.37,72.08,0.56,8.3,0,0,1\n1.51755,13,3.6,1.36,72.99,0.57,8.4,0,0.11,1\n1.51571,12.72,3.46,1.56,73.2,0.67,8.09,0,0.24,1\n1.51763,12.8,3.66,1.27,73.01,0.6,8.56,0,0,1\n1.51589,12.88,3.43,1.4,73.28,0.69,8.05,0,0.24,1\n1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0,0.17,1\n1.51763,12.61,3.59,1.31,73.29,0.58,8.5,0,0,1\n1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0,0,1\n1.51784,12.68,3.67,1.16,73.11,0.61,8.7,0,0,1\n1.52196,14.36,3.85,0.89,71.36,0.15,9.15,0,0,1\n1.51911,13.9,3.73,1.18,72.12,0.06,8.89,0,0,1\n1.51735,13.02,3.54,1.69,72.73,0.54,8.44,0,0.07,1\n1.5175,12.82,3.55,1.49,7
# ...

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host= 'localhost', user = 'root', password = 'root')

# %%
cursor = mydb.cursor()

# %%
cursor.execute('create database glassdata')

# %%
cursor.execute('use glassdata')

# %%
cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('crmdb',),
#  ('glassdata',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('pokemondata',),
#  ('sakila',),
#  ('sanjdbineuron',),
#  ('sys',),
#  ('testdb',),
#  ('world',)]

# %%
cursor.execute('create table glassdata.glasstable(RI float(20,10), Na float(20,10), Mg float(20,10), Al float(20,10), Si float(20,10), K float(20,10), Ca float(20,10), Ba float(20,10), Fe float (20,10), Type float(20,10))')

# %%
with open('glass (1).data', 'r') as f:
    glass_data = csv.reader(f, delimiter = '\n')
    for i in glass_data:
        print({str(i[0])})
# Out:
# {'1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1'}
# {'2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1'}
# {'3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1'}
# {'4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1'}
# {'5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1'}
# {'6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1'}
# {'7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1'}
# {'8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1'}
# {'9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1'}
# {'10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1'}
# {'11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1'}
# {'12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1'}
# {'13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1'}
# {'14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1'}
# {'15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1'}
# {'16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1'}
# ...

# %%
with open('glass.csv', 'r') as f:
    glass_data = csv.reader(f, delimiter = '\n')
    for i in glass_data:
        #print(type(i[0]))
        cursor.execute(f'insert into glasstable values ({str(i[0])})')
        
mydb.commit()

# %%
cursor.execute('select * from glassdata.glasstable')

# %%
cursor.fetchall()
# Out:
# [(None, None, None, None, None, None, None, None, None, None),
#  (1.5210100412,
#   13.6400003433,
#   4.4899997711,
#   1.1000000238,
#   71.7799987793,
#   0.0599999987,
#   8.75,
#   0.0,
#   0.0,
#   1.0),
#  (1.5176099539,
#   13.8900003433,
#   3.5999999046,
#   1.3600000143,
#   72.7300033569,
#   0.4799999893,
#   7.8299999237,
#   0.0,
#   0.0,
#   1.0),
#  (1.5161800385,
#   13.529999733,
#   3.5499999523,
#   1.5399999619,
#   72.9899978638,
#   0.3899999857,
#   7.7800002098,
#   0.0,
#   0.0,
#   1.0),
#  (1.5176600218,
#   13.2100000381,
#   3.6900000572,
#   1.2899999619,
#   72.6100006104,
#   0.5699999928,
#   8.220000267,
#   0.0,
#   0.0,
#   1.0),
#  (1.5174200535,
#   13.2700004578,
#   3.6199998856,
#   1.2400000095,
#   73.0800018311,
#   0.5500000119,
#   8.0699996948,
#   0.0,
#   0.0,
#   1.0),
#  (1.5159599781,
#   12.7899999619,
#   3.6099998951,
#   1.6200000048,
#   72.9700012207,
#   0.6399999857,
#   8.0699996948,
#   0.0,
#   0.2599999905,
#   1.0),
# ...

# %%
with open('glass.csv', 'r') as f:
    glass_data = csv.reader(f, delimiter = '\n')
    for i in glass_data:
        #print(type(i[0]))
        cursor.execute('insert into glasstable values ({values})'.format(values = ((i[0]))))
        
        
mydb.commit()

# %%
cursor.execute("select * from glassdata.glasstable")

# %%
cursor.fetchall()
# Out:
# [(None, None, None, None, None, None, None, None, None, None),
#  (1.5210100412,
#   13.6400003433,
#   4.4899997711,
#   1.1000000238,
#   71.7799987793,
#   0.0599999987,
#   8.75,
#   0.0,
#   0.0,
#   1.0),
#  (1.5176099539,
#   13.8900003433,
#   3.5999999046,
#   1.3600000143,
#   72.7300033569,
#   0.4799999893,
#   7.8299999237,
#   0.0,
#   0.0,
#   1.0),
#  (1.5161800385,
#   13.529999733,
#   3.5499999523,
#   1.5399999619,
#   72.9899978638,
#   0.3899999857,
#   7.7800002098,
#   0.0,
#   0.0,
#   1.0),
#  (1.5176600218,
#   13.2100000381,
#   3.6900000572,
#   1.2899999619,
#   72.6100006104,
#   0.5699999928,
#   8.220000267,
#   0.0,
#   0.0,
#   1.0),
#  (1.5174200535,
#   13.2700004578,
#   3.6199998856,
#   1.2400000095,
#   73.0800018311,
#   0.5500000119,
#   8.0699996948,
#   0.0,
#   0.0,
#   1.0),
#  (1.5159599781,
#   12.7899999619,
#   3.6099998951,
#   1.6200000048,
#   72.9700012207,
#   0.6399999857,
#   8.0699996948,
#   0.0,
#   0.2599999905,
#   1.0),
# ...

# %%
a = 10

print("the value of a is {}".format(a))
# Out:
# the value of a is 10

# %%
import pandas as pd

# %%
pd.read_sql('select * from glassdata.glasstable',mydb)
# Out:
#            RI     Na    Mg    Al         Si     K    Ca    Ba   Fe  Type
# 0         NaN    NaN   NaN   NaN        NaN   NaN   NaN   NaN  NaN   NaN
# 1     1.52101  13.64  4.49  1.10  71.779999  0.06  8.75  0.00  0.0   1.0
# 2     1.51761  13.89  3.60  1.36  72.730003  0.48  7.83  0.00  0.0   1.0
# 3     1.51618  13.53  3.55  1.54  72.989998  0.39  7.78  0.00  0.0   1.0
# 4     1.51766  13.21  3.69  1.29  72.610001  0.57  8.22  0.00  0.0   1.0
# ...       ...    ...   ...   ...        ...   ...   ...   ...  ...   ...
# 1715  1.51623  14.14  0.00  2.88  72.610001  0.08  9.18  1.06  0.0   7.0
# 1716  1.51685  14.92  0.00  1.99  73.059998  0.00  8.40  1.59  0.0   7.0
# 1717  1.52065  14.36  0.00  2.02  73.419998  0.00  8.44  1.64  0.0   7.0
# 1718  1.51651  14.38  0.00  1.94  73.610001  0.00  8.48  1.57  0.0   7.0
# 1719  1.51711  14.23  0.00  2.08  73.360001  0.00  8.62  1.67  0.0   7.0
#
# [1720 rows x 10 columns]

# %%
pd.read_sql("show databases", mydb)
# Out:
#               Database
# 0                crmdb
# 1            glassdata
# 2   information_schema
# 3                mysql
# 4   performance_schema
# 5          pokemondata
# 6               sakila
# 7        sanjdbineuron
# 8                  sys
# 9               testdb
# 10               world

# %%
#pd.read_sql_query('use pokemondata', mydb)

# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host= 'localhost', user = 'root', password = 'root')

# %%
mydb

# %%
cursor = mydb.cursor()

# %%
cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('crmdb',),
#  ('glassdata',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('pokemondata',),
#  ('sakila',),
#  ('sanjdbineuron',),
#  ('sys',),
#  ('testdb',),
#  ('world',)]

# %%
cursor.execute('use glassdata')

# %%
cursor.execute('select * from glasstable')

# %%
cursor.fetchall()
# Out:
# [(None, None, None, None, None, None, None, None, None, None),
#  (1.5210100412,
#   13.6400003433,
#   4.4899997711,
#   1.1000000238,
#   71.7799987793,
#   0.0599999987,
#   8.75,
#   0.0,
#   0.0,
#   1.0),
#  (1.5176099539,
#   13.8900003433,
#   3.5999999046,
#   1.3600000143,
#   72.7300033569,
#   0.4799999893,
#   7.8299999237,
#   0.0,
#   0.0,
#   1.0),
#  (1.5161800385,
#   13.529999733,
#   3.5499999523,
#   1.5399999619,
#   72.9899978638,
#   0.3899999857,
#   7.7800002098,
#   0.0,
#   0.0,
#   1.0),
#  (1.5176600218,
#   13.2100000381,
#   3.6900000572,
#   1.2899999619,
#   72.6100006104,
#   0.5699999928,
#   8.220000267,
#   0.0,
#   0.0,
#   1.0),
#  (1.5174200535,
#   13.2700004578,
#   3.6199998856,
#   1.2400000095,
#   73.0800018311,
#   0.5500000119,
#   8.0699996948,
#   0.0,
#   0.0,
#   1.0),
#  (1.5159599781,
#   12.7899999619,
#   3.6099998951,
#   1.6200000048,
#   72.9700012207,
#   0.6399999857,
#   8.0699996948,
#   0.0,
#   0.2599999905,
#   1.0),
# ...

# %%
cursor.execute('select * from pokemondata.pokemon2')

# %%
cursor.fetchall()
# Out:
# [(None, None, None, None, None, None, None, None),
#  (1, 45, 49, 49, 65, 65, 45, 1),
#  (2, 60, 62, 63, 80, 80, 60, 1),
#  (3, 80, 82, 83, 100, 100, 80, 1),
#  (3, 80, 100, 123, 122, 120, 80, 1),
#  (4, 39, 52, 43, 60, 50, 65, 1),
#  (5, 58, 64, 58, 80, 65, 80, 1),
#  (6, 78, 84, 78, 109, 85, 100, 1),
#  (6, 78, 130, 111, 130, 85, 100, 1),
#  (6, 78, 104, 78, 159, 115, 100, 1),
#  (7, 44, 48, 65, 50, 64, 43, 1),
#  (8, 59, 63, 80, 65, 80, 58, 1),
#  (9, 79, 83, 100, 85, 105, 78, 1),
#  (9, 79, 103, 120, 135, 115, 78, 1),
#  (10, 45, 30, 35, 20, 20, 45, 1),
#  (11, 50, 20, 55, 25, 25, 30, 1),
#  (12, 60, 45, 50, 90, 80, 70, 1),
#  (13, 40, 35, 30, 20, 20, 50, 1),
#  (14, 45, 25, 50, 25, 25, 35, 1),
#  (15, 65, 90, 40, 45, 80, 75, 1),
#  (15, 65, 150, 40, 15, 80, 145, 1),
#  (16, 40, 45, 40, 35, 35, 56, 1),
#  (17, 63, 60, 55, 50, 50, 71, 1),
#  (18, 83, 80, 75, 70, 70, 101, 1),
#  (18, 83, 80, 80, 135, 80, 121, 1),
#  (19, 30, 56, 35, 25, 35, 72, 1),
# ...

# %%
cursor.execute("select Na, Mg, Si, Si, RI from glassdata.glasstable " )

# %%
cursor.fetchall()
# Out:
# [(None, None, None, None, None),
#  (13.6400003433, 4.4899997711, 71.7799987793, 71.7799987793, 1.5210100412),
#  (13.8900003433, 3.5999999046, 72.7300033569, 72.7300033569, 1.5176099539),
#  (13.529999733, 3.5499999523, 72.9899978638, 72.9899978638, 1.5161800385),
#  (13.2100000381, 3.6900000572, 72.6100006104, 72.6100006104, 1.5176600218),
#  (13.2700004578, 3.6199998856, 73.0800018311, 73.0800018311, 1.5174200535),
#  (12.7899999619, 3.6099998951, 72.9700012207, 72.9700012207, 1.5159599781),
#  (13.3000001907, 3.5999999046, 73.0899963379, 73.0899963379, 1.5174299479),
#  (13.1499996185, 3.6099998951, 73.2399978638, 73.2399978638, 1.5175600052),
#  (14.0399999619, 3.5799999237, 72.0800018311, 72.0800018311, 1.5191800594),
#  (13.0, 3.5999999046, 72.9899978638, 72.9899978638, 1.5175499916),
#  (12.720000267, 3.4600000381, 73.1999969482, 73.1999969482, 1.5157099962),
#  (12.8000001907, 3.6600000858, 73.0100021362, 73.0100021362, 1.517629981),
# ...

# %%
cursor.execute('select * from glassdata.glasstable WHERE Type=2.0000000000)

# %%
cursor.fetchall()
# Out:
# [(1.5181800127,
#   13.720000267,
#   0.0,
#   0.5600000024,
#   74.4499969482,
#   0.0,
#   10.9899997711,
#   0.0,
#   0.0,
#   2.0),
#  (1.5181800127,
#   13.720000267,
#   0.0,
#   0.5600000024,
#   74.4499969482,
#   0.0,
#   10.9899997711,
#   0.0,
#   0.0,
#   2.0),
#  (1.5181800127,
#   13.720000267,
#   0.0,
#   0.5600000024,
#   74.4499969482,
#   0.0,
#   10.9899997711,
#   0.0,
#   0.0,
#   2.0),
#  (1.5181800127,
#   13.720000267,
#   0.0,
#   0.5600000024,
#   74.4499969482,
#   0.0,
#   10.9899997711,
#   0.0,
#   0.0,
#   2.0),
#  (1.5181800127,
#   13.720000267,
#   0.0,
#   0.5600000024,
#   74.4499969482,
#   0.0,
#   10.9899997711,
#   0.0,
#   0.0,
#   2.0),
#  (1.5181800127,
#   13.720000267,
#   0.0,
#   0.5600000024,
#   74.4499969482,
#   0.0,
#   10.9899997711,
#   0.0,
#   0.0,
#   2.0),
#  (1.5181800127,
#   13.720000267,
#   0.0,
#   0.5600000024,
#   74.4499969482,
#   0.0,
#   10.9899997711,
#   0.0,
#   0.0,
#   2.0),
#  (1.5181800127,
# ...

# %%
# !pip install passlib

# %%
cursor.execute('delete from glasstable where Type=2.0000000000 ')

# %%
mydb.commit()

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute('UPDATE glasstable SET CA = 115, Ba = 200 where Type =1.0000000000 ')

# %%
mydb.commit()

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute('select * from glasstable')

# %%
cursor.fetchall()
# Out:
# [(None, None, None, None, None, None, None, None, None, None),
#  (1.5210100412,
#   13.6400003433,
#   4.4899997711,
#   1.1000000238,
#   71.7799987793,
#   0.0599999987,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5176099539,
#   13.8900003433,
#   3.5999999046,
#   1.3600000143,
#   72.7300033569,
#   0.4799999893,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5161800385,
#   13.529999733,
#   3.5499999523,
#   1.5399999619,
#   72.9899978638,
#   0.3899999857,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5176600218,
#   13.2100000381,
#   3.6900000572,
#   1.2899999619,
#   72.6100006104,
#   0.5699999928,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5174200535,
#   13.2700004578,
#   3.6199998856,
#   1.2400000095,
#   73.0800018311,
#   0.5500000119,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5159599781,
#   12.7899999619,
#   3.6099998951,
#   1.6200000048,
#   72.9700012207,
#   0.6399999857,
#   115.0,
#   200.0,
#   0.2599999905,
#   1.0),
#  (1.5174299479,
# ...

# %%
cursor.execute('select * from glassdata.glasstable where Mg = 3.5999999046')

# %%
cursor.fetchall()
# Out:
# [(1.5176099539,
#   13.8900003433,
#   3.5999999046,
#   1.3600000143,
#   72.7300033569,
#   0.4799999893,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5174299479,
#   13.3000001907,
#   3.5999999046,
#   1.1399999857,
#   73.0899963379,
#   0.5799999833,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5175499916,
#   13.0,
#   3.5999999046,
#   1.3600000143,
#   72.9899978638,
#   0.5699999928,
#   115.0,
#   200.0,
#   0.1099999994,
#   1.0),
#  (1.5176099539,
#   13.8900003433,
#   3.5999999046,
#   1.3600000143,
#   72.7300033569,
#   0.4799999893,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5174299479,
#   13.3000001907,
#   3.5999999046,
#   1.1399999857,
#   73.0899963379,
#   0.5799999833,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5175499916,
#   13.0,
#   3.5999999046,
#   1.3600000143,
#   72.9899978638,
#   0.5699999928,
#   115.0,
#   200.0,
#   0.1099999994,
#   1.0),
#  (1.5176099539,
#   13.8900003433,
#   3.5999999046,
#   1.3600000143,
#   72.7300033569,
# ...

# %%
cursor.execute('select RI,count(Na) as c from glassdata.glasstable group by RI')

# %%
cursor.fetchall()
# Out:
# [(None, 0),
#  (1.5210100412, 8),
#  (1.5176099539, 16),
#  (1.5161800385, 8),
#  (1.5176600218, 8),
#  (1.5174200535, 8),
#  (1.5159599781, 8),
#  (1.5174299479, 8),
#  (1.5175600052, 8),
#  (1.5191800594, 8),
#  (1.5175499916, 16),
#  (1.5157099962, 8),
#  (1.517629981, 16),
#  (1.5158900023, 8),
#  (1.5174800158, 8),
#  (1.5178400278, 16),
#  (1.5219600201, 8),
#  (1.5191099644, 8),
#  (1.5173499584, 8),
#  (1.5175000429, 8),
#  (1.519659996, 8),
#  (1.517359972, 8),
#  (1.5175100565, 8),
#  (1.5171999931, 8),
#  (1.5176399946, 8),
#  (1.5179300308, 16),
#  (1.5172100067, 8),
#  (1.5176800489, 16),
#  (1.5174700022, 8),
#  (1.5177500248, 8),
#  (1.5175299644, 8),
#  (1.5178300142, 8),
#  (1.5156699419, 8),
#  (1.5190900564, 8),
#  (1.5179699659, 8),
#  (1.5221300125, 16),
#  (1.5177899599, 16),
#  (1.5220999718, 8),
#  (1.517860055, 8),
#  (1.5190000534, 8),
#  (1.51868999, 8),
#  (1.5266699791, 8),
#  (1.5222300291, 8),
#  (1.5189800262, 8),
#  (1.5232000351, 8),
# ...

# %%
cursor.execute('select Na, Mg,count(Mg), Al from glassdata.glasstable group by Mg order by Na')

# %%
cursor.fetchall()
# Out:
# [(None, None, 0, None),
#  (11.029999733, 1.7100000381, 8, 1.5599999428),
#  (11.5600004196, 1.8799999952, 8, 1.5599999428),
#  (12.4499998093, 2.7100000381, 8, 1.2899999619),
#  (12.5600004196, 3.5199999809, 16, 1.4299999475),
#  (12.5699996948, 3.4700000286, 16, 1.3799999952),
#  (12.6099996567, 3.5899999142, 16, 1.3099999428),
#  (12.6400003433, 0.0, 264, 1.6499999762),
#  (12.6800003052, 3.6700000763, 8, 1.1599999666),
#  (12.7100000381, 3.4200000763, 8, 1.2000000477),
#  (12.720000267, 3.4600000381, 8, 1.5599999428),
#  (12.7299995422, 1.8500000238, 8, 1.8600000143),
#  (12.7899999619, 3.6099998951, 16, 1.6200000048),
#  (12.8000001907, 3.6600000858, 24, 1.2699999809),
#  (12.8100004196, 3.5699999332, 16, 1.3500000238),
#  (12.8100004196, 3.5399999619, 40, 1.2300000191),
#  (12.8500003815, 1.6100000143, 8, 2.1700000763),
#  (12.8599996567, 3.5599999428, 16, 1.2699999809),
#  (12.8800001144, 3.4300000668, 16, 1.3999999762),
#  (12.970000267, 0.3300000131, 8, 1.5099999905),
# ...

# %%
cursor.execute('select * from glassdata.glasstable where Mg = 1.7100000381')

# %%
cursor.fetchall()
# Out:
# [(1.521510005,
#   11.029999733,
#   1.7100000381,
#   1.5599999428,
#   73.4400024414,
#   0.5799999833,
#   11.6199998856,
#   0.0,
#   0.0,
#   5.0),
#  (1.521510005,
#   11.029999733,
#   1.7100000381,
#   1.5599999428,
#   73.4400024414,
#   0.5799999833,
#   11.6199998856,
#   0.0,
#   0.0,
#   5.0),
#  (1.521510005,
#   11.029999733,
#   1.7100000381,
#   1.5599999428,
#   73.4400024414,
#   0.5799999833,
#   11.6199998856,
#   0.0,
#   0.0,
#   5.0),
#  (1.521510005,
#   11.029999733,
#   1.7100000381,
#   1.5599999428,
#   73.4400024414,
#   0.5799999833,
#   11.6199998856,
#   0.0,
#   0.0,
#   5.0),
#  (1.521510005,
#   11.029999733,
#   1.7100000381,
#   1.5599999428,
#   73.4400024414,
#   0.5799999833,
#   11.6199998856,
#   0.0,
#   0.0,
#   5.0),
#  (1.521510005,
#   11.029999733,
#   1.7100000381,
#   1.5599999428,
#   73.4400024414,
#   0.5799999833,
#   11.6199998856,
#   0.0,
#   0.0,
#   5.0),
#  (1.521510005,
#   11.029999733,
#   1.7100000381,
# ...

# %%
cursor.execute('select * from pokemondata.pokemon2')

# %%
cursor.fetchall()
# Out:
# [(None, None, None, None, None, None, None, None),
#  (1, 45, 49, 49, 65, 65, 45, 1),
#  (2, 60, 62, 63, 80, 80, 60, 1),
#  (3, 80, 82, 83, 100, 100, 80, 1),
#  (3, 80, 100, 123, 122, 120, 80, 1),
#  (4, 39, 52, 43, 60, 50, 65, 1),
#  (5, 58, 64, 58, 80, 65, 80, 1),
#  (6, 78, 84, 78, 109, 85, 100, 1),
#  (6, 78, 130, 111, 130, 85, 100, 1),
#  (6, 78, 104, 78, 159, 115, 100, 1),
#  (7, 44, 48, 65, 50, 64, 43, 1),
#  (8, 59, 63, 80, 65, 80, 58, 1),
#  (9, 79, 83, 100, 85, 105, 78, 1),
#  (9, 79, 103, 120, 135, 115, 78, 1),
#  (10, 45, 30, 35, 20, 20, 45, 1),
#  (11, 50, 20, 55, 25, 25, 30, 1),
#  (12, 60, 45, 50, 90, 80, 70, 1),
#  (13, 40, 35, 30, 20, 20, 50, 1),
#  (14, 45, 25, 50, 25, 25, 35, 1),
#  (15, 65, 90, 40, 45, 80, 75, 1),
#  (15, 65, 150, 40, 15, 80, 145, 1),
#  (16, 40, 45, 40, 35, 35, 56, 1),
#  (17, 63, 60, 55, 50, 50, 71, 1),
#  (18, 83, 80, 75, 70, 70, 101, 1),
#  (18, 83, 80, 80, 135, 80, 121, 1),
#  (19, 30, 56, 35, 25, 35, 72, 1),
# ...

# %%
cursor.execute('select count(Generation) from pokemondata.pokemon2 ')

# %%
cursor.fetchall()
# Out:
# [(800,)]

# %%
cursor.execute('select count(*), Generation from pokemondata.pokemon2 group by Attack')

# %%
cursor.fetchall()
# Out:
# [(1, None),
#  (3, 1),
#  (4, 1),
#  (6, 1),
#  (40, 1),
#  (7, 1),
#  (5, 1),
#  (5, 1),
#  (14, 1),
#  (3, 1),
#  (9, 1),
#  (6, 1),
#  (4, 1),
#  (3, 1),
#  (20, 1),
#  (8, 1),
#  (27, 1),
#  (13, 1),
#  (7, 1),
#  (30, 1),
#  (11, 1),
#  (33, 1),
#  (37, 1),
#  (3, 1),
#  (3, 1),
#  (33, 1),
#  (30, 1),
#  (32, 1),
#  (3, 1),
#  (7, 1),
#  (2, 1),
#  (7, 1),
#  (1, 1),
#  (31, 1),
#  (2, 1),
#  (4, 1),
#  (37, 1),
#  (39, 1),
#  (26, 1),
#  (17, 1),
#  (18, 1),
#  (21, 1),
#  (21, 1),
#  (5, 1),
#  (2, 1),
#  (14, 1),
#  (2, 1),
#  (2, 1),
#  (3, 1),
#  (9, 1),
#  (6, 1),
#  (2, 1),
#  (1, 1),
#  (1, 2),
#  (3, 2),
#  (4, 2),
#  (1, 2),
#  (1, 2),
#  (1, 2),
#  (5, 3),
#  (2, 3),
#  (1, 3),
#  (1, 3),
#  (6, 3),
#  (1, 3),
#  (4, 3),
#  (1, 3),
#  (3, 3),
#  (3, 3),
#  (1, 3),
#  (4, 3),
#  (3, 3),
#  (3, 4),
#  (2, 4),
#  (7, 4),
#  (2, 4),
#  (1, 4),
#  (1, 4),
#  (3, 4),
#  (1, 4),
#  (4, 4),
#  (2, 4),
#  (1, 4),
#  (2, 4),
#  (1, 4),
#  (2, 4),
#  (2, 4),
#  (2, 4),
# ...

# %%
cursor.execute('select count(Generation) from pokemondata.pokemon2')

# %%
cursor.fetchall()
# Out:
# [(800,)]

# %%
cursor.execute('select count(*), Generation from pokemondata.pokemon2 where Generation = 2')

# %%
cursor.fetchall()
# Out:
# [(106, 2)]

# %%
cursor.execute('select count(*), Attack from pokemondata.pokemon2 where Attack = 45')

# %%
cursor.fetchall()
# Out:
# [(27, 45)]

# %%
cursor.execute('drop table pokemondata.pokemon2')

# %%
mydb.commit()

# %%
cursor.execute('select count(*), Attack from pokemondata.pokemon2 where Attack = 45')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     522                 query = query.encode('utf-8')
# --> 523             self._cmysql.query(query,
#     524                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Table 'pokemondata.pokemon2' doesn't exist
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10584/3662584741.py in <module>
# ----> 1 cursor.execute('select count(*), Attack from pokemondata.pokemon2 where Attack = 45')
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     267
#     268         try:
# ...

# %%
cursor.execute('select * from glassdata.glasstable')

# %%
cursor.fetchall()
# Out:
# [(None, None, None, None, None, None, None, None, None, None),
#  (1.5210100412,
#   13.6400003433,
#   4.4899997711,
#   1.1000000238,
#   71.7799987793,
#   0.0599999987,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5176099539,
#   13.8900003433,
#   3.5999999046,
#   1.3600000143,
#   72.7300033569,
#   0.4799999893,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5161800385,
#   13.529999733,
#   3.5499999523,
#   1.5399999619,
#   72.9899978638,
#   0.3899999857,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5176600218,
#   13.2100000381,
#   3.6900000572,
#   1.2899999619,
#   72.6100006104,
#   0.5699999928,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5174200535,
#   13.2700004578,
#   3.6199998856,
#   1.2400000095,
#   73.0800018311,
#   0.5500000119,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5159599781,
#   12.7899999619,
#   3.6099998951,
#   1.6200000048,
#   72.9700012207,
#   0.6399999857,
#   115.0,
#   200.0,
#   0.2599999905,
#   1.0),
#  (1.5174299479,
# ...

# %%
cursor.execute('select Na,si,Mg from glassdata.glasstable where Na = 13.6400003433 or si = 71.7799987793')

# %%
cursor.fetchall()
# Out:
# [(13.6400003433, 71.7799987793, 4.4899997711),
#  (13.6400003433, 73.0, 3.6500000954),
#  (13.6400003433, 72.6500015259, 3.5399999619),
#  (13.6400003433, 71.7799987793, 4.4899997711),
#  (13.6400003433, 73.0, 3.6500000954),
#  (13.6400003433, 72.6500015259, 3.5399999619),
#  (13.6400003433, 71.7799987793, 4.4899997711),
#  (13.6400003433, 73.0, 3.6500000954),
#  (13.6400003433, 72.6500015259, 3.5399999619),
#  (13.6400003433, 71.7799987793, 4.4899997711),
#  (13.6400003433, 73.0, 3.6500000954),
#  (13.6400003433, 72.6500015259, 3.5399999619),
#  (13.6400003433, 71.7799987793, 4.4899997711),
#  (13.6400003433, 73.0, 3.6500000954),
#  (13.6400003433, 72.6500015259, 3.5399999619),
#  (13.6400003433, 71.7799987793, 4.4899997711),
#  (13.6400003433, 73.0, 3.6500000954),
#  (13.6400003433, 72.6500015259, 3.5399999619),
#  (13.6400003433, 71.7799987793, 4.4899997711),
#  (13.6400003433, 73.0, 3.6500000954),
#  (13.6400003433, 72.6500015259, 3.5399999619),
# ...

# %%
cursor.execute('select Na,si,Mg from glassdata.glasstable where Na = 13.6400003433 and si = 71.7799987793')

# %%
cursor.fetchall()
# Out:
# [(13.6400003433, 71.7799987793, 4.4899997711),
#  (13.6400003433, 71.7799987793, 4.4899997711),
#  (13.6400003433, 71.7799987793, 4.4899997711),
#  (13.6400003433, 71.7799987793, 4.4899997711),
#  (13.6400003433, 71.7799987793, 4.4899997711),
#  (13.6400003433, 71.7799987793, 4.4899997711),
#  (13.6400003433, 71.7799987793, 4.4899997711),
#  (13.6400003433, 71.7799987793, 4.4899997711)]

# %%
cursor.execute('select * from glassdata.glasstable')

# %%
cursor.fetchall()
# Out:
# [(None, None, None, None, None, None, None, None, None, None),
#  (1.5210100412,
#   13.6400003433,
#   4.4899997711,
#   1.1000000238,
#   71.7799987793,
#   0.0599999987,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5176099539,
#   13.8900003433,
#   3.5999999046,
#   1.3600000143,
#   72.7300033569,
#   0.4799999893,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5161800385,
#   13.529999733,
#   3.5499999523,
#   1.5399999619,
#   72.9899978638,
#   0.3899999857,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5176600218,
#   13.2100000381,
#   3.6900000572,
#   1.2899999619,
#   72.6100006104,
#   0.5699999928,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5174200535,
#   13.2700004578,
#   3.6199998856,
#   1.2400000095,
#   73.0800018311,
#   0.5500000119,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5159599781,
#   12.7899999619,
#   3.6099998951,
#   1.6200000048,
#   72.9700012207,
#   0.6399999857,
#   115.0,
#   200.0,
#   0.2599999905,
#   1.0),
#  (1.5174299479,
# ...

# %%
cursor.execute("select * from glassdata.glasstable where Al like '1.139%'")

# %%
cursor.fetchall()
# Out:
# [(1.5174299479,
#   13.3000001907,
#   3.5999999046,
#   1.1399999857,
#   73.0899963379,
#   0.5799999833,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5174700022,
#   12.8400001526,
#   3.5,
#   1.1399999857,
#   73.2699966431,
#   0.5600000024,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5174299479,
#   13.3000001907,
#   3.5999999046,
#   1.1399999857,
#   73.0899963379,
#   0.5799999833,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5174700022,
#   12.8400001526,
#   3.5,
#   1.1399999857,
#   73.2699966431,
#   0.5600000024,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5174299479,
#   13.3000001907,
#   3.5999999046,
#   1.1399999857,
#   73.0899963379,
#   0.5799999833,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5174700022,
#   12.8400001526,
#   3.5,
#   1.1399999857,
#   73.2699966431,
#   0.5600000024,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5174299479,
#   13.3000001907,
#   3.5999999046,
#   1.1399999857,
#   73.0899963379,
#   0.5799999833,
#   115.0,
# ...

# %%
cursor.execute('select * from glassdata.glasstable')

# %%
cursor.fetchall()
# Out:
# [(None, None, None, None, None, None, None, None, None, None),
#  (1.5210100412,
#   13.6400003433,
#   4.4899997711,
#   1.1000000238,
#   71.7799987793,
#   0.0599999987,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5176099539,
#   13.8900003433,
#   3.5999999046,
#   1.3600000143,
#   72.7300033569,
#   0.4799999893,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5161800385,
#   13.529999733,
#   3.5499999523,
#   1.5399999619,
#   72.9899978638,
#   0.3899999857,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5176600218,
#   13.2100000381,
#   3.6900000572,
#   1.2899999619,
#   72.6100006104,
#   0.5699999928,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5174200535,
#   13.2700004578,
#   3.6199998856,
#   1.2400000095,
#   73.0800018311,
#   0.5500000119,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5159599781,
#   12.7899999619,
#   3.6099998951,
#   1.6200000048,
#   72.9700012207,
#   0.6399999857,
#   115.0,
#   200.0,
#   0.2599999905,
#   1.0),
#  (1.5174299479,
# ...

# %%
cursor.execute('select * from glassdata.glasstable order by Na desc')

# %%
cursor.fetchall()
# Out:
# [(1.5111500025,
#   17.3799991608,
#   0.0,
#   0.3400000036,
#   75.4100036621,
#   0.0,
#   6.6500000954,
#   0.0,
#   0.0,
#   6.0),
#  (1.5111500025,
#   17.3799991608,
#   0.0,
#   0.3400000036,
#   75.4100036621,
#   0.0,
#   6.6500000954,
#   0.0,
#   0.0,
#   6.0),
#  (1.5111500025,
#   17.3799991608,
#   0.0,
#   0.3400000036,
#   75.4100036621,
#   0.0,
#   6.6500000954,
#   0.0,
#   0.0,
#   6.0),
#  (1.5111500025,
#   17.3799991608,
#   0.0,
#   0.3400000036,
#   75.4100036621,
#   0.0,
#   6.6500000954,
#   0.0,
#   0.0,
#   6.0),
#  (1.5111500025,
#   17.3799991608,
#   0.0,
#   0.3400000036,
#   75.4100036621,
#   0.0,
#   6.6500000954,
#   0.0,
#   0.0,
#   6.0),
#  (1.5111500025,
#   17.3799991608,
#   0.0,
#   0.3400000036,
#   75.4100036621,
#   0.0,
#   6.6500000954,
#   0.0,
#   0.0,
#   6.0),
#  (1.5111500025,
#   17.3799991608,
#   0.0,
#   0.3400000036,
#   75.4100036621,
#   0.0,
#   6.6500000954,
#   0.0,
#   0.0,
#   6.0),
#  (1.5111500025,
# ...

# %%
cursor.execute("select * from (select * from glassdata.glasstable where Na = 17.3799991608) as a where Na <18")

# %%
cursor.fetchall()
# Out:
# [(1.5111500025,
#   17.3799991608,
#   0.0,
#   0.3400000036,
#   75.4100036621,
#   0.0,
#   6.6500000954,
#   0.0,
#   0.0,
#   6.0),
#  (1.5111500025,
#   17.3799991608,
#   0.0,
#   0.3400000036,
#   75.4100036621,
#   0.0,
#   6.6500000954,
#   0.0,
#   0.0,
#   6.0),
#  (1.5111500025,
#   17.3799991608,
#   0.0,
#   0.3400000036,
#   75.4100036621,
#   0.0,
#   6.6500000954,
#   0.0,
#   0.0,
#   6.0),
#  (1.5111500025,
#   17.3799991608,
#   0.0,
#   0.3400000036,
#   75.4100036621,
#   0.0,
#   6.6500000954,
#   0.0,
#   0.0,
#   6.0),
#  (1.5111500025,
#   17.3799991608,
#   0.0,
#   0.3400000036,
#   75.4100036621,
#   0.0,
#   6.6500000954,
#   0.0,
#   0.0,
#   6.0),
#  (1.5111500025,
#   17.3799991608,
#   0.0,
#   0.3400000036,
#   75.4100036621,
#   0.0,
#   6.6500000954,
#   0.0,
#   0.0,
#   6.0),
#  (1.5111500025,
#   17.3799991608,
#   0.0,
#   0.3400000036,
#   75.4100036621,
#   0.0,
#   6.6500000954,
#   0.0,
#   0.0,
#   6.0),
#  (1.5111500025,
# ...

# %%
cursor.execute('select  * from glassdata.glasstable')
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27156/4205109993.py in <module>
# ----> 1 cursor.execute('select  * from glassdata.glasstable')
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     241         if not self._cnx or self._cnx.is_closed():
#     242             raise errors.ProgrammingError("Cursor is not connected", 2055)
# --> 243         self._cnx.handle_unread_result()
#     244
#     245         stmt = ''
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in handle_unread_result(self, prepared)
#     792             self.consume_results()
#     793         elif unread_result:
# --> 794             raise errors.InternalError("Unread result found")
#     795
#     796     def reset_session(self, user_variables=None, session_variables=None):
#
# ...

# %%
cursor.fetchall()
# Out:
# [(None, None, None, None, None, None, None, None, None, None),
#  (1.5210100412,
#   13.6400003433,
#   4.4899997711,
#   1.1000000238,
#   71.7799987793,
#   0.0599999987,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5176099539,
#   13.8900003433,
#   3.5999999046,
#   1.3600000143,
#   72.7300033569,
#   0.4799999893,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5161800385,
#   13.529999733,
#   3.5499999523,
#   1.5399999619,
#   72.9899978638,
#   0.3899999857,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5176600218,
#   13.2100000381,
#   3.6900000572,
#   1.2899999619,
#   72.6100006104,
#   0.5699999928,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5174200535,
#   13.2700004578,
#   3.6199998856,
#   1.2400000095,
#   73.0800018311,
#   0.5500000119,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5159599781,
#   12.7899999619,
#   3.6099998951,
#   1.6200000048,
#   72.9700012207,
#   0.6399999857,
#   115.0,
#   200.0,
#   0.2599999905,
#   1.0),
#  (1.5174299479,
# ...

# %%
cursor.execute('select * from glassdata.glasstable group by Na')

# %%
cursor.execute('select * from glassdata.glasstable group by Mg having count(Mg) > 3')
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27156/2435638637.py in <module>
# ----> 1 cursor.execute('select * from glassdata.glasstable group by Mg having count(Mg) > 3')
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     241         if not self._cnx or self._cnx.is_closed():
#     242             raise errors.ProgrammingError("Cursor is not connected", 2055)
# --> 243         self._cnx.handle_unread_result()
#     244
#     245         stmt = ''
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in handle_unread_result(self, prepared)
#     792             self.consume_results()
#     793         elif unread_result:
# --> 794             raise errors.InternalError("Unread result found")
#     795
# ...

# %%
cursor.fetchall()
# Out:
# [(None, None, None, None, None, None, None, None, None, None),
#  (1.5210100412,
#   13.6400003433,
#   4.4899997711,
#   1.1000000238,
#   71.7799987793,
#   0.0599999987,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5176099539,
#   13.8900003433,
#   3.5999999046,
#   1.3600000143,
#   72.7300033569,
#   0.4799999893,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5161800385,
#   13.529999733,
#   3.5499999523,
#   1.5399999619,
#   72.9899978638,
#   0.3899999857,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5176600218,
#   13.2100000381,
#   3.6900000572,
#   1.2899999619,
#   72.6100006104,
#   0.5699999928,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5174200535,
#   13.2700004578,
#   3.6199998856,
#   1.2400000095,
#   73.0800018311,
#   0.5500000119,
#   115.0,
#   200.0,
#   0.0,
#   1.0),
#  (1.5159599781,
#   12.7899999619,
#   3.6099998951,
#   1.6200000048,
#   72.9700012207,
#   0.6399999857,
#   115.0,
#   200.0,
#   0.2599999905,
#   1.0),
#  (1.5174299479,
# ...

# %%
cursor.execute('create database cardata')

# %%
mydb.commit()

# %%
cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('cardata',),
#  ('crmdb',),
#  ('glassdata',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('pokemondata',),
#  ('sakila',),
#  ('sanjdbineuron',),
#  ('sys',),
#  ('testdb',),
#  ('world',)]

# %%
cursor.execute('use cardata')

# %%
cursor.execute('drop table cartable')

# %%
cursor.execute('create table cartable( col1 varchar(20), col2 varchar(20), col3 varchar(20), col4 varchar(20), col5 varchar(20), col6 varchar(20), col7 varchar(20)) ')

# %%
cursor.execute('insert into cartable values("vhigh","vhigh",2,2,"small","low","unacc")')
mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     522                 query = query.encode('utf-8')
# --> 523             self._cmysql.query(query,
#     524                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Table 'cardata.cartable' doesn't exist
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27156/2861590990.py in <module>
# ----> 1 cursor.execute('insert into cartable values("vhigh","vhigh",2,2,"small","low","unacc")')
#       2 mydb.commit()
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     267
#     268         try:
# ...

# %%
import pandas as pd

# %%
pd.DataFrame('car_evaluation.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27156/1505535985.py in <module>
# ----> 1 pd.DataFrame('car_evaluation.csv')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     728         else:
#     729             if index is None or columns is None:
# --> 730                 raise ValueError("DataFrame constructor not properly called!")
#     731
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
df = pd.read_csv('car_evaluation.csv')

# %%
df.head()
# Out:
#     col1   col2 col3 col4   col5  col6   col7
# 0  vhigh  vhigh    2    2  small   low  unacc
# 1  vhigh  vhigh    2    2  small   med  unacc
# 2  vhigh  vhigh    2    2  small  high  unacc
# 3  vhigh  vhigh    2    2    med   low  unacc
# 4  vhigh  vhigh    2    2    med   med  unacc

# %%
df.to_csv('cardata.csv', index=False)

# %%
import csv
with open('cardata.csv' , 'r') as f:
    reader = csv.reader(f, delimiter = '\n')
    for data in reader:
        cursor.execute('insert into cartable values({values})'.format(values = ((data[0]))))
mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     522                 query = query.encode('utf-8')
# --> 523             self._cmysql.query(query,
#     524                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Unknown column 'vhigh' in 'field list'
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27156/1876337121.py in <module>
#       3     reader = csv.reader(f, delimiter = '\n')
#       4     for data in reader:
# ----> 5         cursor.execute('insert into cartable values({values})'.format(values = ((data[0]))))
#       6 mydb.commit()
#
# ...

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute('drop table cartable')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     522                 query = query.encode('utf-8')
# --> 523             self._cmysql.query(query,
#     524                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Unknown table 'cardata.cartable'
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27156/2709985923.py in <module>
# ----> 1 cursor.execute('drop table cartable')
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     267
#     268         try:
# --> 269             result = self._cnx.cmd_query(stmt, raw=self._raw,
# ...

# %%
mydb.commit()

# %%
import csv
with open('car_evaluation.csv' , 'r') as f:
    reader = csv.reader(f, delimiter = '\n')
    header = next(reader)
    print(header)
    row = []
    for data in reader:
        row.append(data)
# Out:
# ['col1,col2,col3,col4,col5,col6,col7']

# %%
print(row)
# Out:
# [['vhigh,vhigh,2,2,small,low,unacc'], ['vhigh,vhigh,2,2,small,med,unacc'], ['vhigh,vhigh,2,2,small,high,unacc'], ['vhigh,vhigh,2,2,med,low,unacc'], ['vhigh,vhigh,2,2,med,med,unacc'], ['vhigh,vhigh,2,2,med,high,unacc'], ['vhigh,vhigh,2,2,big,low,unacc'], ['vhigh,vhigh,2,2,big,med,unacc'], ['vhigh,vhigh,2,2,big,high,unacc'], ['vhigh,vhigh,2,4,small,low,unacc'], ['vhigh,vhigh,2,4,small,med,unacc'], ['vhigh,vhigh,2,4,small,high,unacc'], ['vhigh,vhigh,2,4,med,low,unacc'], ['vhigh,vhigh,2,4,med,med,unacc'], ['vhigh,vhigh,2,4,med,high,unacc'], ['vhigh,vhigh,2,4,big,low,unacc'], ['vhigh,vhigh,2,4,big,med,unacc'], ['vhigh,vhigh,2,4,big,high,unacc'], ['vhigh,vhigh,2,more,small,low,unacc'], ['vhigh,vhigh,2,more,small,med,unacc'], ['vhigh,vhigh,2,more,small,high,unacc'], ['vhigh,vhigh,2,more,med,low,unacc'], ['vhigh,vhigh,2,more,med,med,unacc'], ['vhigh,vhigh,2,more,med,high,unacc'], ['vhigh,vhigh,2,more,big,low,unacc'], ['vhigh,vhigh,2,more,big,med,unacc'], ['vhigh,vhigh,2,more,big,high,unacc']
# ...

# %%
   # with open('glass.csv', 'r') as f:
   # glass_data = csv.reader(f, delimiter = '\n')
    #for i in glass_data:
    #print(type(i[0]))
    #cursor.execute(f'insert into glasstable values ({str(i[0])})')
    #mydb.commit()

# %%
cursor.execute('insert into cartable values()')

# %%
cursor.execute('insert into pokemondata.pokemon1 values(1, "Bulbasaur", "Grass", "Poison", 45,49,49,65,65,45,1, "False")')
